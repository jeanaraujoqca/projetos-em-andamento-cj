# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.select import Select
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import TimeoutException
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from time import sleep

class Equipe:
    def __init__(self):
        '''Possibilitar que acessemos os sites dentro do navegador Chrome.'''
        self.service = Service(ChromeDriverManager().install())
        self.options = webdriver.ChromeOptions()
        self.driver = webdriver.Chrome(service=self.service, options=self.options)
        self.driver.maximize_window()
        timeout = 60
        self.wait = WebDriverWait(self.driver, timeout)
    
    def acessar_performa(self, url, email, senha):
        '''Acessa a plataforma do Performa de acordo com o link passado, email e senha compartilhadas para entrar na conta.'''
        self.url = url
        self.email = email
        self.senha = senha
        
        self.driver.get(self.url)
        
        # esperar ate o elemento seja encontrado para fazer inserir as info de email e senha da conta
        try:
            elemento_esperado_email = self.wait.until(EC.visibility_of_element_located((
                By.XPATH, "//input[@id='Email']"
            )))

            email_input = self.driver.find_element(By.XPATH, "//input[@id='Email']")
            senha_input = self.driver.find_element(By.XPATH, "//input[@id='Senha']")
            entrar_button = self.driver.find_element(By.XPATH, "//button[@class='btn btn-bricky pull-right']")

            email_input.send_keys(self.email)
            senha_input.send_keys(self.senha)
            entrar_button.click()
        except TimeoutException:
            print("O elemento não foi encontrado no tempo especificado!")
    
    def home(self):
        '''Voltar para a página principal'''
        self.driver.get("https://performaqca.seven.adv.br/AcessoCorrespondente/main")
        sleep(3)

    def aguardando_aceite(self, url_aceite):
        '''Possibilita entrar na pagina referente ao widget Solicitações Aguardando Aceite.'''
        self.url_aceite = url_aceite
        self.driver.get(self.url_aceite)
    
    def aguardando_checkin(self, url_checkin):
        '''Possibilita entrar na pagina referente ao widget Solicitações Aguardando CheckIn.'''
        self.url_checkin = url_checkin
        self.driver.get(self.url_checkin)

    def checar_solicitacao_aceite(self):
        '''Faz a checagem das solicitações. Verifica se realmente existe algum processo para o usuário dar aceite.'''
        try:
            elemento_esperado_texto = self.wait.until(EC.visibility_of_element_located((
                By.XPATH, "//div//ol//li[@class='active']"
            )))
            try:
                registro_localizado = self.driver.find_element(By.XPATH, "//div//tbody//tr//td[text()='Nenhum registro localizado']")
                registro_localizado = registro_localizado.text
                if registro_localizado == "Nenhum registro localizado":
                    voltar_pagina_inicial = self.driver.find_element(By.XPATH, "//div//ol[@class='breadcrumb']//li//a[text()='Home']")
                    voltar_pagina_inicial = voltar_pagina_inicial.get_attribute("href")
                    self.driver.get(voltar_pagina_inicial)
                    sleep(2)
                    return False
            except Exception as e:
                pass
        except TimeoutException:
            print("O elemento não foi encontrado no tempo especificado!")
        
        try:
            exibicao_resultado = self.driver.find_elements(By.XPATH, "//div[@class='pag col-md-12 space-top']//div//span")
            exibicao_resultado = exibicao_resultado[0].text
            exibicao_resultado = int(exibicao_resultado.split()[-1])
            if exibicao_resultado > 0:
                sleep(2)
                return True
        except Exception as e:
            pass
        except TimeoutException:
            print("O elemento não foi encontrado no tempo especificado!")
        return False

    def total_paginas(self):
        '''Calcula a quantidade de paginas que temos dentro dessas atividades'''
        exibicao_resultado = self.driver.find_elements(By.XPATH, "//div[@class='pag col-md-12 space-top']//div//span")
        exibicao_resultado = exibicao_resultado[0].text
        exibicao_resultado = int(exibicao_resultado.split()[-1])
        total_itens = exibicao_resultado
        itens_por_pagina = 25
        total_paginas = (total_itens + itens_por_pagina - 1) // itens_por_pagina
        return int(total_paginas)
    
    def buscar_links_processos(self):
        '''Percorre as paginas para pegar os links dos processos.'''
        checagem = self.checar_solicitacao_aceite()
        lista_links_servicos = []
        if checagem:
            # checar se temos apenas 1 pagina ou se temos > 1 pagina. Se tiver > 1 pagina, percorrer todas as paginas e extrair links (PASSAR POR ENQT)
            numero_paginas = self.total_paginas()
            if numero_paginas == 1:
                try:
                    servicos = self.driver.find_elements(By.XPATH, "//div//table//tbody//tr[contains(@class,'gridrow')]//td//a[@title='visualizar']")
                    for link_servico in servicos:
                        link = link_servico.get_attribute("href")
                        lista_links_servicos.append(link)
                except Exception as e:
                    print("Erro em buscar_links_processos: ", e)
                return lista_links_servicos
            elif numero_paginas > 1:
                # no momento do desenvolvimento nao temos o botao para passar para a proxima pagina e testar
                for pag in range(1, numero_paginas+1):
                    pagina_button = self.driver.find_elements(By.XPATH, f"//ul[@class='pagination ']//li//a[@href='{pag}']")[0]
                    pagina_button.click()
                    sleep(5)
                    try:
                        servicos = self.driver.find_elements(By.XPATH, "//div//table//tbody//tr[contains(@class,'gridrow')]//td//a[@title='visualizar']")
                        for link_servico in servicos:
                            link = link_servico.get_attribute("href")
                            lista_links_servicos.append(link)
                    except Exception as e:
                        print("Erro em buscar_links_processos: ", e)
                return lista_links_servicos
        return lista_links_servicos

    def aceitar_solicitacao(self):
        '''Executa a atividade de dar aceite'''
        lista_servicos = self.buscar_links_processos()
        # verifica se a lista de links possui links para entrar
        if lista_servicos is not None:
            for s in lista_servicos:
                self.driver.get(s)
                sleep(2)
                try:
                    elemento_esperado_acoes = self.wait.until(EC.visibility_of_element_located((
                        By.XPATH, "//div[@id='box-dadosprincipais']//div//div//div//div//div//button[@class='btn btn-acoes']"
                    )))
                    acoes_button = self.driver.find_element(By.XPATH, "//div[@id='box-dadosprincipais']//div//div//div//div//div//button[@class='btn btn-acoes dropdown-toggle']")
                    acoes_button.click()
                    try:
                        elemento_esperado_aceitar_solicitacao = self.wait.until(EC.visibility_of_element_located((
                            By.XPATH, "//ul[@class='dropdown-menu']//li//a[@id='buttonAceitarSolicitacao']"
                        )))
                        aceitar_solicitacao_button = self.driver.find_element(By.XPATH, "//ul[@class='dropdown-menu']//li//a[@id='buttonAceitarSolicitacao']")
                        aceitar_solicitacao_button.click()
                        sleep(3)
                        yes_button = self.driver.find_element(By.XPATH, "//div[@class='modal-content']//div[@class='modal-footer']//button[@class='bootboxSim btn btn-primary'][text() = 'Sim']")
                        yes_button.click()
                        sleep(2)
                    except TimeoutException:
                        print("O elemento não foi encontrado no tempo especificado!")
                    except Exception as e:
                        print("Erro em: ", e)
                except TimeoutException:
                    print("O elementro não foi encontrado no tempo especificado!")
                except Exception as e:
                    print("Erro em: ", e)
        # voltar para a primeira pagina
        self.home()

    def preencher_informacoes(self):
        '''Executa a atividade de preencher as informacoes do aguardando checkin'''
        lista_servicos = self.buscar_links_processos()
        # verifica se a lista de links possui links para entrar
        if lista_servicos is not None:
            for s in lista_servicos:
                self.driver.get(s)
                sleep(2)
                try:
                    elemento_esperado_acoes = self.wait.until(EC.visibility_of_element_located((
                        By.XPATH, "//div[@id='box-dadosprincipais']//div//div//div//div//div//button[@class='btn btn-acoes']"
                    )))
                    acoes_button = self.driver.find_element(By.XPATH, "//div[@id='box-dadosprincipais']//div//div//div//div//div//button[@class='btn btn-acoes dropdown-toggle']")
                    acoes_button.click()
                    caminho_editar = self.driver.find_element(By.XPATH, "//ul[@class='dropdown-menu']//li//a[@title='Docs. de Representação']")
                    caminho_preencher = self.driver.find_element(By.XPATH, "//ul[@class='dropdown-menu']//li//a[@title='Docs. de Representação']")
                    if caminho_editar.text == "Editar Docs. de Representação":
                        # passar para o proximo link
                        continue
                    elif caminho_preencher.text == "Solicitar Docs. de Representação":
                        caminho_preencher.click()
                        sleep(2)
                        #providenciar carta de preposicao? SIM
                        carta = self.driver.find_element(By.XPATH, "//div//label[2]//div//ins")
                        carta.click()
                        sleep(1)
                        #nome
                        nome = self.driver.find_element(By.XPATH, "//div//input[@id='NomeCompletoPreposto']")
                        nome.send_keys('MANOEL AUGUSTO SOBRAL FILHO')
                        #rg
                        rg = self.driver.find_element(By.XPATH, "//div//input[@id='RGPreposto']")
                        rg.send_keys('11.538.008 SDS/PE')
                        #cpf
                        cpf = self.driver.find_element(By.XPATH, "//div//input[@id='CPFPreposto']")
                        cpf.send_keys('149.868.894-27')
                        #providenciar subestabelecimento - NAO
                        subestabelecimento = self.driver.find_element(By.XPATH, '//*[@id="docsRepresentacaoForm"]/div[4]/div/label[1]/div/ins')
                        subestabelecimento.click()
                        #observacoes
                        obs = self.driver.find_element(By.XPATH, "//div//div//textarea[@id='ObservacoesDocsRepresentacao']")
                        obs.send_keys('MANOEL AUGUSTO SOBRAL FILHO-11.538.008-SDS/PE-149.868.894-27-(81)996809326-manoelsobral@queirozcavalcanti.adv.br')
                        #salvar
                        salvar = self.driver.find_element(By.XPATH, '//*[@id="dialog-modal"]/div/div/div[3]/button[1]')
                        salvar.click()
                        sleep(2)
                except TimeoutException:
                    print("O elementro não foi encontrado no tempo especificado!")
                except Exception as e:
                    print("Erro em: ", e)
        # voltar para a primeira pagina
        self.home()
    
    def fechar_chrome(self):
        self.driver.quit()

if __name__ == "__main__":
    app = Equipe()
    url = "https://performaqca.seven.adv.br/AcessoCorrespondente/main"
    email = "manoelsobral@queirozcavalcanti.adv.br"
    senha = "prazo"

    app.acessar_performa(url=url, email=email, senha=senha)
    sleep(2)

    # aguardando aceite
    url_aceite = "https://performaqca.seven.adv.br/AcessoCorrespondente/solicitacao/myList?statusId=2&modoExibicao=2"
    app.aguardando_aceite(url_aceite=url_aceite)
    sleep(3)
    app.aceitar_solicitacao()
    sleep(3)

    # aguardando check in
    url_checkin = "https://performaqca.seven.adv.br/AcessoCorrespondente/solicitacao/myList?statusId=12&modoExibicao=2&operation=aguardandocheckin"
    app.aguardando_checkin(url_checkin=url_checkin)
    sleep(3)
    app.preencher_informacoes()
    sleep(3)

    app.home()
    sleep(3)
    app.fechar_chrome()
    print("O programa finalizou com sucesso!")
else:
    print("O sistema não conseguiu carregar adequadamente!")
# Out:
# O programa finalizou com sucesso!

# %%
# PARA INSTALAR AS BIBLIOTECAS BASTA UTILIZAR O SINAL DE ! ANTES DO COMANDO pip instal {nome_da_lib}
# !pip install pandas selenium webdriver-manager openpyxl

# %%
# !pyinstaller --onefile app_MANOEL.py
# Out:
# 2685 INFO: PyInstaller: 6.6.0, contrib hooks: 2024.6
# 2685 INFO: Python: 3.11.7 (conda)
# 2706 INFO: Platform: Windows-10-10.0.19044-SP0
# 2706 INFO: wrote C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\app_MANOEL.spec
# 2716 INFO: Extending PYTHONPATH with paths
# ['C:\\Users\\allisonferreira\\Documents\\Codigo - Aceite e Preenchimento - '
#  'Prepostos']
# 3164 INFO: checking Analysis
# 3164 INFO: Building Analysis because Analysis-00.toc is non existent
# 3164 INFO: Running Analysis Analysis-00.toc
# 3164 INFO: Target bytecode optimization level: 0
# 3164 INFO: Initializing module dependency graph...
# 3164 INFO: Caching module graph hooks...
# 3214 INFO: Analyzing base_library.zip ...
# 10322 INFO: Loading module hook 'hook-encodings.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 12964 INFO: Loading module hook 'hook-heapq.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 13403 INFO: Loading module hook 'hook-pickle.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 15815 INFO: Caching module dependency graph...
# 15917 INFO: Looking for Python shared library...
# 15927 INFO: Using Python shared library: C:\Users\allisonferreira\AppData\Local\anaconda3\python311.dll
# 15927 INFO: Analyzing C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\app_MANOEL.py
# 15948 INFO: Loading module hook 'hook-selenium.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 16381 INFO: Loading module hook 'hook-platform.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 16677 INFO: Loading module hook 'hook-certifi.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 17654 INFO: Loading module hook 'hook-xml.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 17664 INFO: Loading module hook 'hook-xml.dom.domreg.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 18633 INFO: Loading module hook 'hook-charset_normalizer.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 18807 INFO: Loading module hook 'hook-cryptography.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 24657 INFO: Loading module hook 'hook-bcrypt.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 24943 INFO: Loading module hook 'hook-IPython.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 27097 INFO: Loading module hook 'hook-difflib.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 27323 INFO: Loading module hook 'hook-matplotlib.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 27831 INFO: Loading module hook 'hook-numpy.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\numpy\\_pyinstaller'...
# 29034 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 29762 INFO: Loading module hook 'hook-sysconfig.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 30100 INFO: Loading module hook 'hook-psutil.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 31393 INFO: Loading module hook 'hook-packaging.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 31474 INFO: Processing pre-safe import module hook gi from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-gi.py'.
# 31598 INFO: Loading module hook 'hook-PIL.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 31741 INFO: Loading module hook 'hook-PIL.Image.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 34103 INFO: Loading module hook 'hook-xml.etree.cElementTree.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 34337 INFO: Loading module hook 'hook-pycparser.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 34768 INFO: Loading module hook 'hook-setuptools.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 40331 INFO: Processing pre-safe import module hook distutils from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-distutils.py'.
# 40331 INFO: Processing pre-find module path hook distutils from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-distutils.py'.
# 40708 INFO: Loading module hook 'hook-distutils.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 40775 INFO: Loading module hook 'hook-distutils.util.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 40963 INFO: Loading module hook 'hook-importlib_metadata.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 41748 INFO: Loading module hook 'hook-pkg_resources.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 47626 INFO: Loading module hook 'hook-PIL.ImageFilter.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 48215 INFO: Loading module hook 'hook-jinja2.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 50500 INFO: Processing pre-safe import module hook six.moves from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_safe_import_module\\hook-six.moves.py'.
# 51569 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 52349 INFO: Loading module hook 'hook-pygments.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 61570 INFO: Loading module hook 'hook-lib2to3.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 62814 INFO: Loading module hook 'hook-py.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 63293 INFO: Loading module hook 'hook-pytest.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 64499 INFO: Loading module hook 'hook-wcwidth.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 64583 INFO: Loading module hook 'hook-backports.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 65601 INFO: Loading module hook 'hook-jedi.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 67274 INFO: Loading module hook 'hook-parso.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 67827 INFO: Loading module hook 'hook-docutils.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 78402 INFO: Loading module hook 'hook-sphinx.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# Traceback (most recent call last):
#   File "<string>", line 2, in <module>
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\sphinx\application.py", line 27, in <module>
#     from sphinx.environment import BuildEnvironment
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\sphinx\environment\__init__.py", line 23, in <module>
#     from sphinx.events import EventManager
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\sphinx\events.py", line 13, in <module>
#     from sphinx.util.inspect import safe_getattr
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\sphinx\util\inspect.py", line 18, in <module>
#     from sphinx.pycode.ast import ast  # for py36-37
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\sphinx\pycode\__init__.py", line 11, in <module>
#     from zipfile import ZipFile
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\zipfile.py", line 19, in <module>
#     import pathlib
#   File "C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\pathlib.py", line 10, in <module>
#     from collections import Sequence
# ImportError: cannot import name 'Sequence' from 'collections' (C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\collections\__init__.py)
# 83344 INFO: Loading module hook 'hook-babel.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 83844 INFO: Loading module hook 'hook-pytz.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 85487 INFO: Loading module hook 'hook-sqlite3.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 87947 INFO: Loading module hook 'hook-nbformat.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 88156 INFO: Loading module hook 'hook-jsonschema.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 88308 INFO: Loading module hook 'hook-jsonschema_specifications.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 89080 INFO: Loading module hook 'hook-platformdirs.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 90031 INFO: Loading module hook 'hook-zmq.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 93316 INFO: Loading module hook 'hook-nacl.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 93511 INFO: Loading module hook 'hook-pywintypes.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 94657 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 94690 INFO: Loading module hook 'hook-PyQt5.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 95458 INFO: Loading module hook 'hook-shelve.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 95473 INFO: Loading module hook 'hook-cloudpickle.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 95567 INFO: Processing module hooks...
# 96456 INFO: Loading module hook 'hook-zope.interface.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 97748 INFO: Loading module hook 'hook-matplotlib.backends.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 97748 INFO: Matplotlib backend selection method: automatic discovery of used backends
# 98219 INFO: Found configured default matplotlib backend: module://matplotlib_inline.backend_inline
# 98219 INFO: Selected matplotlib backends: ['module://matplotlib_inline.backend_inline']
# 98487 INFO: Loading module hook 'hook-PIL.SpiderImagePlugin.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 101042 INFO: Loading module hook 'hook-setuptools.msvc.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 101719 INFO: Loading module hook 'hook-setuptools._distutils.command.check.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 104419 INFO: Loading module hook 'hook-_tkinter.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 104419 INFO: checking Tree
# 104419 INFO: Building Tree because Tree-00.toc is non existent
# 104419 INFO: Building Tree Tree-00.toc
# 104684 INFO: checking Tree
# 104684 INFO: Building Tree because Tree-01.toc is non existent
# 104684 INFO: Building Tree Tree-01.toc
# 104714 INFO: checking Tree
# 104714 INFO: Building Tree because Tree-02.toc is non existent
# 104714 INFO: Building Tree Tree-02.toc
# 104780 INFO: Performing binary vs. data reclassification (4986 entries)
# 106995 INFO: Looking for ctypes DLLs
# 107229 INFO: Analyzing run-time hooks ...
# 107239 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 107239 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 107249 INFO: Processing pre-find module path hook _pyi_rth_utils from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\pre_find_module_path\\hook-_pyi_rth_utils.py'.
# 107249 INFO: Loading module hook 'hook-_pyi_rth_utils.py' from 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks'...
# 107249 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 107260 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_setuptools.py'
# 107260 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 107260 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_mplconfig.py'
# 107280 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_cryptography_openssl.py'
# 107280 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 107280 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_traitlets.py'
# 107286 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pyqt5.py'
# 107290 INFO: Including run-time hook 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 107434 INFO: Looking for dynamic libraries
# C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\PyInstaller\building\build_main.py:199: UserWarning: The numpy.array_api submodule is still experimental. See NEP 47.
#   __import__(package)
# 0.00s - Debugger warning: It seems that frozen modules are being used, which may
# 0.00s - make the debugger miss breakpoints. Please pass -Xfrozen_modules=off
# 0.00s - to python to disable frozen modules.
# 0.00s - Note: Debugging will proceed. Set PYDEVD_DISABLE_FILE_VALIDATION=1 to disable this validation.
# C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated and will be removed in a future release
#   "class": algorithms.Blowfish,
# 111407 INFO: Extra DLL search directories (AddDllDirectory): []
# 111407 INFO: Extra DLL search directories (PATH): []
# 113804 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_blacs_intelmpi_ilp64.2.dll'.
# 113804 WARNING: Library not found: could not resolve 'pgc.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_pgi_thread.2.dll'.
# 113804 WARNING: Library not found: could not resolve 'pgf90.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_pgi_thread.2.dll'.
# 113804 WARNING: Library not found: could not resolve 'pgmath.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_pgi_thread.2.dll'.
# 113804 WARNING: Library not found: could not resolve 'impi.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_blacs_intelmpi_lp64.2.dll'.
# 113804 WARNING: Library not found: could not resolve 'sycl6.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\omptarget.sycl.wrap.dll'.
# 113804 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_blacs_msmpi_lp64.2.dll'.
# 113812 WARNING: Library not found: could not resolve 'msmpi.dll', dependency of 'C:\\Users\\allisonferreira\\AppData\\Local\\anaconda3\\Library\\bin\\mkl_blacs_msmpi_ilp64.2.dll'.
# 114070 INFO: Warnings written to C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\build\app_MANOEL\warn-app_MANOEL.txt
# 114345 INFO: Graph cross-reference written to C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\build\app_MANOEL\xref-app_MANOEL.html
# 114900 INFO: checking PYZ
# 114900 INFO: Building PYZ because PYZ-00.toc is non existent
# 114900 INFO: Building PYZ (ZlibArchive) C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\build\app_MANOEL\PYZ-00.pyz
# 118398 INFO: Building PYZ (ZlibArchive) C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\build\app_MANOEL\PYZ-00.pyz completed successfully.
# 118664 INFO: checking PKG
# 118664 INFO: Building PKG because PKG-00.toc is non existent
# 118664 INFO: Building PKG (CArchive) app_MANOEL.pkg
# 230870 INFO: Building PKG (CArchive) app_MANOEL.pkg completed successfully.
# 231181 INFO: Bootloader C:\Users\allisonferreira\AppData\Local\anaconda3\Lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 231181 INFO: checking EXE
# 231181 INFO: Building EXE because EXE-00.toc is non existent
# 231181 INFO: Building EXE from EXE-00.toc
# 231188 INFO: Copying bootloader EXE to C:\Users\allisonferreira\Documents\Codigo - Aceite e Preenchimento - Prepostos\dist\app_MANOEL.exe
# 231512 INFO: Copying icon to EXE
# 231543 INFO: Copying 0 resources to EXE
# 231543 INFO: Embedding manifest in EXE
# 231543 WARNING: Execution of 'write_manifest_to_executable' failed on attempt #1 / 20: error(110, 'EndUpdateResourceW', 'O sistema não pode abrir o dispositivo ou arquivo especificado.'). Retrying in 0.05 second(s)...
# 231626 INFO: Appending PKG archive to EXE
# 258639 INFO: Fixing EXE headers
# 305506 INFO: Building EXE from EXE-00.toc completed successfully.
