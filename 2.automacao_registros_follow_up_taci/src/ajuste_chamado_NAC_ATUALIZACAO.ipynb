# %%
import os
import pandas as pd
from datetime import date
from time import sleep
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.common.exceptions import TimeoutException
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager


# Organizando o diretorio e pegando o file path que sera utilizado para o carregamento da base da dados
BASE_DIR = os.getcwd()
file_path = [os.path.join(BASE_DIR, file) for file in os.listdir(BASE_DIR) if file.endswith('.xlsx')][0]

df = pd.read_excel(file_path, engine='openpyxl')

# config de login
link = 'https://performaqca.seven.adv.br/main'

# config e inicializacao de browser
service = Service(ChromeDriverManager().install())
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service, options=options)
driver.maximize_window()
timeout = 30
wait = WebDriverWait(driver, timeout)

# entrar na plataforma performa
driver.get(link)
print('Esperando o tempo de login e carregamento da pagina')
sleep(40)

print('Iniciando o preenchimento')
for i, email_adv in enumerate(df['Email Advogado']):
    email_adv = df.loc[i, 'Email Advogado']
    telefone_adv = df.loc[i, 'Telefones Advogado']
    wpp_adv = df.loc[i, 'Whatsapp Advogado']
    processo = df.loc[i, 'Pasta Cliente'] # numero do processo
    nome_adv = df.loc[i, 'Nome Advogado']
    proposta_ofertada_valor = df.loc[i, 'Ultima proposta']  # foi adicionado essa variavel para inserir no campo de Proposta Ofertada na atualizacao do Follow Up de Acordo
    
    link = f"https://performaqca.seven.adv.br/processo/details/{int(processo)}"

    driver.get(link)
    sleep(5)
    try:
        # clicar em negociacao
        negociacao_button = driver.find_element(By.XPATH, "//a[@data-toggle='tab']//i[@class='fa fa-money']")
        negociacao_button.click()
        sleep(3)
    
        # verifica se eh duda sena e se o status está como negociacao ou negociacao pos sentenca
        status_acordo = driver.find_element(By.XPATH, '//*[@id="negociacaoList"]/div[1]/table/tbody/tr[1]/td[2]/span')
        status_text = status_acordo.text
        responsavel_acordo = driver.find_elements(By.XPATH, "//table[@class='table  table-striped']//tbody//tr//td//span")[3]
        responsavel_acordo = responsavel_acordo.text
        if (status_text == 'Em Negociação' or status_text == 'Em Negociação Pós Sentença') and (responsavel_acordo == "Maria Eduarda de Sena (Alterar Responsável)"):
            # clicar em "NOVO FOLLOW UP ACORDO"
            followup_button = driver.find_element(By.XPATH, "//button[@class='btn btn-export']")
            followup_button.click()
            sleep(3)
    
            # clicar em adv da parte
            advogado_parte = driver.find_elements(By.XPATH, "//div[@class='iradio_minimal-red']//ins[@class='iCheck-helper']")[1]
            advogado_parte.click()
            sleep(1)
            
            # inserir valor de proposta ofertada
            proposta_ofertada = driver.find_element(By.XPATH, "//div[@class='row']//div[@class='col-md-6']//div[@class='form-group']//input[@id='PropostaOfertada']")
            proposta_ofertada.send_keys(proposta_ofertada_valor)
            sleep(2)
    
            # digitar a observacao
            campo_observacao = driver.find_element(By.XPATH, "//textarea[@class='form-control']")
            campo_observacao.send_keys(f"AF em negociação\nNome do Advogado: {nome_adv}\nEmail: {email_adv}\nTelefones: {telefone_adv}\nWhatsApp: {wpp_adv}") # ISSO AQUI QUE VAI MUDAR
            sleep(1)
    
            # clicar em salvar
            botao_salvar = driver.find_element(By.XPATH, "//button[@class='btn btn-primary salvar']")
            botao_salvar.click()
    
            print(f"Foi realizado o preenchimento das informações do processo: {int(processo)}")
            sleep(3)
    except TimeoutException:
        print(f'Erro no processo {int(processo)}')
    except Exception:
        print(f'Erro no processo {int(processo)}')

sleep(2)

driver.quit()
print("\nO processo foi concluído!")
# Out:
# Esperando o tempo de login e carregamento da pagina
# Iniciando o preenchimento
# Foi realizado o preenchimento das informações do processo: 841122
# Foi realizado o preenchimento das informações do processo: 1073279
# Foi realizado o preenchimento das informações do processo: 728932
# Foi realizado o preenchimento das informações do processo: 1047132
# Foi realizado o preenchimento das informações do processo: 788097
# Foi realizado o preenchimento das informações do processo: 1073289
# Foi realizado o preenchimento das informações do processo: 843764
# Foi realizado o preenchimento das informações do processo: 1064532
# Foi realizado o preenchimento das informações do processo: 1068136
# Foi realizado o preenchimento das informações do processo: 1070202
# Foi realizado o preenchimento das informações do processo: 1074589
# Foi realizado o preenchimento das informações do processo: 986641
# Foi realizado o preenchimento das informações do processo: 638883
# Foi realizado o preenchimento das informações do processo: 684789
# Foi realizado o preenchimento das informações do processo: 678900
# Foi realizado o preenchimento das informações do processo: 779408
# Foi realizado o preenchimento das informações do processo: 661087
# Foi realizado o preenchimento das informações do processo: 565904
# Foi realizado o preenchimento das informações do processo: 762233
# Foi realizado o preenchimento das informações do processo: 593535
# Foi realizado o preenchimento das informações do processo: 656166
# Foi realizado o preenchimento das informações do processo: 676710
# Foi realizado o preenchimento das informações do processo: 957888
# Foi realizado o preenchimento das informações do processo: 487018
# Foi realizado o preenchimento das informações do processo: 678580
# Erro no processo 731594
# Erro no processo 766118
# Foi realizado o preenchimento das informações do processo: 1032867
# Foi realizado o preenchimento das informações do processo: 1041633
# Foi realizado o preenchimento das informações do processo: 1041631
# Foi realizado o preenchimento das informações do processo: 842160
# Foi realizado o preenchimento das informações do processo: 780431
# Foi realizado o preenchimento das informações do processo: 854843
# Foi realizado o preenchimento das informações do processo: 1041304
# Foi realizado o preenchimento das informações do processo: 1041312
# Foi realizado o preenchimento das informações do processo: 1041737
# Foi realizado o preenchimento das informações do processo: 969485
# Foi realizado o preenchimento das informações do processo: 1032954
# Foi realizado o preenchimento das informações do processo: 1041302
# Foi realizado o preenchimento das informações do processo: 853769
# Foi realizado o preenchimento das informações do processo: 1041788
# Foi realizado o preenchimento das informações do processo: 1041795
# Foi realizado o preenchimento das informações do processo: 812190
# Foi realizado o preenchimento das informações do processo: 777951
# Foi realizado o preenchimento das informações do processo: 773519
# Foi realizado o preenchimento das informações do processo: 696051
# Foi realizado o preenchimento das informações do processo: 691736
# Foi realizado o preenchimento das informações do processo: 1002152
# Foi realizado o preenchimento das informações do processo: 787516
# Foi realizado o preenchimento das informações do processo: 841391
# Foi realizado o preenchimento das informações do processo: 656102
# Foi realizado o preenchimento das informações do processo: 607146
# Foi realizado o preenchimento das informações do processo: 688028
# Foi realizado o preenchimento das informações do processo: 868330
# Foi realizado o preenchimento das informações do processo: 1016056
# Foi realizado o preenchimento das informações do processo: 1040609
# Foi realizado o preenchimento das informações do processo: 1045617
# Foi realizado o preenchimento das informações do processo: 1034601
# Foi realizado o preenchimento das informações do processo: 1037755
# Foi realizado o preenchimento das informações do processo: 1033761
# Foi realizado o preenchimento das informações do processo: 1061737
# Foi realizado o preenchimento das informações do processo: 1068997
# Foi realizado o preenchimento das informações do processo: 929580
# Foi realizado o preenchimento das informações do processo: 887098
# Foi realizado o preenchimento das informações do processo: 613782
# Foi realizado o preenchimento das informações do processo: 1071764
# Foi realizado o preenchimento das informações do processo: 1068135
# Foi realizado o preenchimento das informações do processo: 761814
# Foi realizado o preenchimento das informações do processo: 610907
# Foi realizado o preenchimento das informações do processo: 537539
# Foi realizado o preenchimento das informações do processo: 1056208
# Foi realizado o preenchimento das informações do processo: 953804
# Foi realizado o preenchimento das informações do processo: 1017709
# Foi realizado o preenchimento das informações do processo: 991077
# Foi realizado o preenchimento das informações do processo: 991214
# Foi realizado o preenchimento das informações do processo: 991234
# Foi realizado o preenchimento das informações do processo: 991282
# Foi realizado o preenchimento das informações do processo: 991478
# Foi realizado o preenchimento das informações do processo: 991138
# Foi realizado o preenchimento das informações do processo: 991306
# Foi realizado o preenchimento das informações do processo: 991263
# Foi realizado o preenchimento das informações do processo: 991067
# Foi realizado o preenchimento das informações do processo: 991139
# Foi realizado o preenchimento das informações do processo: 991205
# Foi realizado o preenchimento das informações do processo: 991136
# Foi realizado o preenchimento das informações do processo: 991021
# Foi realizado o preenchimento das informações do processo: 991016
# Foi realizado o preenchimento das informações do processo: 990953
# Foi realizado o preenchimento das informações do processo: 990983
# Foi realizado o preenchimento das informações do processo: 846863
# Foi realizado o preenchimento das informações do processo: 244092
# Foi realizado o preenchimento das informações do processo: 962103
# Erro no processo 839764
# Erro no processo 991308
# Erro no processo 990984
# Foi realizado o preenchimento das informações do processo: 1040296
# Foi realizado o preenchimento das informações do processo: 991464
# Foi realizado o preenchimento das informações do processo: 991393
# Foi realizado o preenchimento das informações do processo: 991445
# Foi realizado o preenchimento das informações do processo: 791728
# Foi realizado o preenchimento das informações do processo: 245903
# Foi realizado o preenchimento das informações do processo: 991235
# Foi realizado o preenchimento das informações do processo: 579495
# Foi realizado o preenchimento das informações do processo: 991430
# Foi realizado o preenchimento das informações do processo: 28837
# Foi realizado o preenchimento das informações do processo: 991361
# Foi realizado o preenchimento das informações do processo: 991268
# Foi realizado o preenchimento das informações do processo: 991153
# Foi realizado o preenchimento das informações do processo: 991161
# Foi realizado o preenchimento das informações do processo: 991223
# Erro no processo 991221
# Foi realizado o preenchimento das informações do processo: 991088
# Foi realizado o preenchimento das informações do processo: 991002
# Foi realizado o preenchimento das informações do processo: 990965
# Foi realizado o preenchimento das informações do processo: 990838
# Foi realizado o preenchimento das informações do processo: 990819
# Foi realizado o preenchimento das informações do processo: 587797
# Foi realizado o preenchimento das informações do processo: 549585
# Foi realizado o preenchimento das informações do processo: 785833
#
# O processo foi concluído!
